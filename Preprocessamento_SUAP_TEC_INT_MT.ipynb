# %%
import sklearn
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importantar o dataset
# #### O arquivo precisa está na mesma pasta do notebook

# %%
dfs = pd.read_csv('dataset_suap_tecnico_integrado_monteiro.csv', sep=';'  , engine='python')

# %% [markdown]
# ## Análise do conjunto de dados

# %% [markdown]
# ### Analisando os primeiros valores e o cabeçalho

# %%
dfs.head()
# Out:
#      ID     Matricula  Ano letivo  Periodo Letivo Periodo na Matriz  \
# 0  1828  201615500018        2016               1                 1
# 1  1829  201615500018        2016               1                 1
# 2  1830  201615500018        2016               1                 1
# 3  1831  201615500018        2016               1                 1
# 4  1832  201615500018        2016               1                 1
#
#   Codigo do Componente Descricao do Componente  CH do Componente Nota  \
# 0             TIN.0003                   Artes                67   76
# 1             TIN.0022              Biologia I                67   75
# 2             TIN.0112       Educacao Fisica I                67   92
# 3             TIN.0086             Filosofia I                33   88
# 4             TIN.0125                Fisica I                67   89
#
#    % Frequencia  ... Faixa de Renda (SISTEC)  Forma de Ingresso  \
# 0           100  ...              0<RFP<=0,5               PSCT
# ...

# %%
dfs_cadastro_geral = dfs[['Matricula','Curso','Ano de Ingresso','Cor/Raca','Cota MEC','Cota SISTEC','Data de Nascimento','Faixa de Renda (SISTEC)','Nome da Escola de Origem','Sexo','Tipo Escola de Origem','Zona Residencial do Aluno','Situacao no Diario','Situacao no Curso','Codigo do Componente']]

# %%
dfs_cadastro_geral = dfs_cadastro_geral.sort_values(by="Matricula")

# %%
dfs_cadastro_geral[dfs_cadastro_geral.Matricula == 201825130017]
# Out:
# Empty DataFrame
# Columns: [Matricula, Curso, Ano de Ingresso, Cor/Raca, Cota MEC, Cota SISTEC, Data de Nascimento, Faixa de Renda (SISTEC), Nome da Escola de Origem, Sexo, Tipo Escola de Origem, Zona Residencial do Aluno, Situacao no Diario, Situacao no Curso, Codigo do Componente]
# Index: []

# %%
dfs_cadastro_geral = dfs_cadastro_geral[(~dfs_cadastro_geral['Situacao no Diario'].str.contains("Cancelado"))]

# %%
dfs_cadastro_geral.drop_duplicates(subset ='Matricula', 
                     keep='last', inplace = True)

# %%
searchfor2 = [
'TIN.0056',
'TIN.0113',
'TIN.0087',
'TIN.0033',
'TIN.0027',
'TIN.0028',
'TIN.0030',
'TIN.0021',
'TIN.0161',
'TIN.0024',
'TIN.0091',
'TIN.0043',
'TIN.0008',
'TIN.0700',
'TIN.0132',
'TIN.0673',
'TIN.0675',
'TIN.0891',
'TIN.0893'
]

# %%
searchfor_cod_disciplinas1 = [
'TIN.0022',
'TIN.0138',
'TIN.0128',
'TIN.0112',
'TIN.0086',
'TIN.0125',
'TIN.0194',
'TIN.0352',
'TIN.0559',
'TIN.0351',
'TIN.0018',
'TIN.0001',
'TIN.0124',
'TIN.0090',
'TIN.0322',
'TIN.0014',
'TIN.0133',
'TIN.0150',
'TIN.0253'
]

# %% [markdown]
# dfs_cadastro_geral_disciplinas_concluidas_segundo_ano = dfs_cadastro_geral[(dfs_cadastro_geral['Codigo do Componente'].str.contains('|'.join(searchfor2)))]

# %%
dfs_cadastro_geral_disciplinas_concluidas_primeiro_ano = dfs_cadastro_geral[(dfs_cadastro_geral['Codigo do Componente'].str.contains('|'.join(searchfor_cod_disciplinas1)))]

# %%
dfs_cadastro_geral_disciplinas_concluidas_primeiro_ano.shape
# Out:
# (232, 15)

# %%
dfs_cadastro_geral_disciplinas_concluidas_primeiro_ano.head(50)
# Out:
#          Matricula                                              Curso  \
# 324   201615500003  550 - Tecnico em Manutencao e Suporte em Infor...
# 273   201615500007  550 - Tecnico em Manutencao e Suporte em Infor...
# 2176  201615500008  550 - Tecnico em Manutencao e Suporte em Infor...
# 206   201615500009  550 - Tecnico em Manutencao e Suporte em Infor...
# 1668  201615500014  550 - Tecnico em Manutencao e Suporte em Infor...
# 1378  201615500016  550 - Tecnico em Manutencao e Suporte em Infor...
# 1230  201615500019  550 - Tecnico em Manutencao e Suporte em Infor...
# 1280  201615500024  550 - Tecnico em Manutencao e Suporte em Infor...
# 1497  201615500026  550 - Tecnico em Manutencao e Suporte em Infor...
# 768   201615500030  550 - Tecnico em Manutencao e Suporte em Infor...
# 856   201615500033  550 - Tecnico em Manutencao e Suporte em Infor...
# 105   201615500034  550 - Tecnico em Manutencao e Suporte em Infor...
# ...

# %%
del dfs_cadastro_geral_disciplinas_concluidas_primeiro_ano['Codigo do Componente']

# %% [markdown]
# dfs_cadastro_msi = dfs_cadastro_geral[(dfs_cadastro_geral['Curso'].str.contains("550"))]

# %%
dfs_resumo_geral = dfs[['Matricula','Codigo do Componente','Descricao do Componente','Nota']]

# %%
dfs_resumo_geral['Nota'] = dfs_resumo_geral['Nota'].replace(['-'],'0')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# dfs_resumo_geral = dfs_resumo_geral[(~dfs_resumo_geral['Situacao no Diario'].str.contains("Cancelado"))]

# %% [markdown]
# dfs_resumo_geral = dfs_resumo_geral[(~dfs_resumo_geral['Situacao no Curso'].str.contains("Cancelado"))]

# %%
dfs_resumo_geral.head()
# Out:
#       Matricula Codigo do Componente Descricao do Componente Nota
# 0  201615500018             TIN.0003                   Artes   76
# 1  201615500018             TIN.0022              Biologia I   75
# 2  201615500018             TIN.0112       Educacao Fisica I   92
# 3  201615500018             TIN.0086             Filosofia I   88
# 4  201615500018             TIN.0125                Fisica I   89

# %%
dfs_resumo_geral['Nota'] = dfs_resumo_geral['Nota'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfs_resumo_geral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16204 entries, 0 to 16203
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Matricula                16204 non-null  int64
#  1   Codigo do Componente     16204 non-null  object
#  2   Descricao do Componente  16204 non-null  object
#  3   Nota                     16204 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 506.5+ KB

# %% [markdown]
# dfs_resumo_msi[(dfs_resumo_msi.Matricula == 202015500035)]

# %%
dfs_resumo_geral_primeiro_ano = dfs_resumo_geral[(dfs_resumo_geral['Codigo do Componente'].str.contains('|'.join(searchfor_cod_disciplinas1)))]

# %%
df_pivot_geral = dfs_resumo_geral_primeiro_ano.pivot_table(index="Matricula", columns=["Descricao do Componente"], values=["Nota"], aggfunc=np.mean)

# %% [markdown]
# df_pivot_geral = pd.merge(dfs_cadastro_geral,
#                  df_pivot_geral,
#                  on='Matricula',
#                  how='left')

# %%
dfs_pivot_geral_primeiro_ano = dfs_resumo_geral_primeiro_ano.pivot_table(index="Matricula", columns=["Descricao do Componente"], values=["Nota"], aggfunc=np.mean)

# %%
dfs_pivot_geral_primeiro_ano = pd.merge(dfs_cadastro_geral_disciplinas_concluidas_primeiro_ano,
                 dfs_pivot_geral_primeiro_ano,
                 on='Matricula', 
                 how='left')
# Out:
# /home/jp/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
dfs_pivot_geral_primeiro_ano.reset_index(drop=True)
# Out:
#         Matricula                                              Curso  \
# 0    201615500003  550 - Tecnico em Manutencao e Suporte em Infor...
# 1    201615500007  550 - Tecnico em Manutencao e Suporte em Infor...
# 2    201615500008  550 - Tecnico em Manutencao e Suporte em Infor...
# 3    201615500009  550 - Tecnico em Manutencao e Suporte em Infor...
# 4    201615500014  550 - Tecnico em Manutencao e Suporte em Infor...
# ..            ...                                                ...
# 227  201915520039  552 - Tecnico em Edificacoes Integrado ao Ensi...
# 228  201915520041  552 - Tecnico em Edificacoes Integrado ao Ensi...
# 229  201915520042  552 - Tecnico em Edificacoes Integrado ao Ensi...
# 230  201915520044  552 - Tecnico em Edificacoes Integrado ao Ensi...
# 231  201915520045  552 - Tecnico em Edificacoes Integrado ao Ensi...
#
#      Ano de Ingresso Cor/Raca  \
# 0               2016   Branca
# 1               2016    Preta
# 2               2016   Branca
# ...

# %%
dfs_pivot_geral_primeiro_ano.to_csv('suap_geral_primeiro_ano.csv', encoding='utf-8',sep=';')
